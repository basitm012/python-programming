# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Enter your salary amount: "))
appointed_year = int(input("Enter your Appointed Year: "))

if appointed_year<=2021:
    print("Your net bonus amount is Rs.",salary*5//100)
else:
    print("You're not eligibe for bonus amount")

print("Your salary is Rs.",salary)
print("You have been serving company from",appointed_year )
# Out:
# Your net bonus amount is Rs. 2500
# Your salary is Rs. 50000
# You have been serving company from 2009

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age: "))

if age>18:
    print("You're eligibe for voting.")
else:
    print("You're not eligibe for voting.")
# Out:
# You're not eligibe for voting.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter your number:"))

if num % 2 == 0:
    print("Your number is even")

else:
    print("Your number is odd")

print("Your number is", num)
# Out:
# Your number is odd
# Your number is 5

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter your number:"))

if num % 7 == 0:
    print("This number is divisible by 7")
else:
    print("This number is not divisible by 7")
# Out:
# This number is divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter your number:"))

if num % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
num = int(input("Enter your number:"))

print (num % 10)
# Out:
# 9

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter your shape length:"))
breadth = int(input("Enter your shape breadth:"))

if length == breadth:
    print("This shape is Square")
else:
    print("This shape is Rectangle")
# Out:
# This shape is Rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("Enter your first number"))
num2 = int(input("Enter your second number"))

if num1 > num2:
    print ("Greatest number is", num1)
else:
    print ("Greatest number is", num2)
# Out:
# Greatest number is 5

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
quantity = int(input("Enter your quantity:"))

total_cost = quantity * 100 #per unit costs Rs. 100
discounted_amount = total_cost*10/100

if total_cost >= 1000:
    print ("Total Cost is", total_cost)
    print ("Your Discount amount is Rs.", total_cost-discounted_amount)
else:
    print ("Total Cost is", total_cost)
    print ("No Discount Applied. Please purchase for at least Rs. 1000 to get discount")
# Out:
# Total Cost is 1500
# Your Discount amount is Rs. 1350.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter your marks:"))

if marks > 80 and marks <= 100:
    print("Your Grade is A")
elif marks > 60 and marks <= 80:
    print("Your Grade is B")
elif marks > 50 and marks <= 60:
    print("Your Grade is C")
elif marks > 45 and marks <= 50:
    print("Your Grade is D")
elif marks > 25 and marks <= 45:
    print ("Your Grade is E")
elif marks > 0 and marks <= 25:
    print ("Your Grade is F")
else:
    print("Invalid Input")
# Out:
# Your Grade is E

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
total_classes = int(input("Enter total classes held:"))
attended_classes = int(input("Enter number of classes attended:"))

classes_attended_percentage = (attended_classes/total_classes*100)

print (f"{classes_attended_percentage:.2f}%")

if classes_attended_percentage > 70:
    print("You are allowed to sit in exam")
else:
    print("You are not allowed")
# Out:
# 81.08%
# You are allowed to sit in exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
medical_cause = input("Do you have any medical cause? (Yes/No)").lower()

if medical_cause == "yes":
    print ("you are allowed to sit")
elif medical_cause == "no":
    print ("you are not allowed to sit")
else:
    print ("ERROR")
# Out:
# you are not allowed to sit

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = 2000

if year % 400 == 0:
    print ("This is Leap Year")

elif year % 4 == 0 and year % 100 != 0:
    print("This is Leap Year")

else:
    print("This is not Leap Year")
# Out:
# This is Leap Year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter your age (numbers only)"))
gender = input("Enter your gender (Male/Female): ").lower()
merital_status = (input("Are you married? (Yes/No)")).lower()

if gender == "female":
    print ("You can work only in urban areas.")
elif gender == "male" and age > 20 and age <= 40:
    print("You can work anywhere.")
elif gender == "male" and age > 40 and age <= 60:
    print ("You can work only in urban areas.")
else:
    print ("Error")
# Out:
# Error

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
unit = int(input("Enter Units"))

if unit >= 1 and unit < 100:
    print (f"Rs.{unit * 0} (No Charge)")
elif unit >= 100 and unit < 200:
    print (f"Rs.{unit * 5} (Rs. 5 per unit)")
else:
    print (f"Rs.{unit * 10} (Rs. 10 per unit)")

print ("Your total electricity units are", unit)
# Out:
# Rs.825 (Rs. 5 per unit)
# Your total electricity units are 165

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter first person age:"))
age2 = int(input("Enter second person age:"))
age3 = int(input("Enter third person age:"))

oldest = age2
youngest = age1

if age2 > oldest:
    oldest = age2
if age3 > oldest:
    oldest = age3

if age2 < youngest:
    youngest = age2
if age3 < youngest:
    youngest = age3

print ("Youngest age is", youngest)
print ("Oldest age is", oldest)
# Out:
# Youngest age is 10
# Oldest age is 30
