# %%
tpl = input("Enter you numbers:")
print (tpl [::-1])
# Out:
# 0,9,8,7,6,5,4,3,2,1

# %%
tpl = input("Enter you numbers:")

largest = tpl[0]

for num in tpl:
    if num > largest:
        largest = num

print (largest)
# Out:
# 9
