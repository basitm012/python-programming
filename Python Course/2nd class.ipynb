# %%
print ("hello")
# Out:
# hello

# %% [markdown]
# # Variables

# %%
name = "Abdul Basit"

# %%
print (name)
# Out:
# Abdul Basit

# %%
type (name)
# Out:
# str

# %%
id (name)
# Out:
# 1743913220528

# %%
name_2 = "ABC"

# %% [markdown]
# - Numbers --> `Integers` eg: 35
# - Decimal --> `float` eg: 35.5
# - Characters/Alphats --> `string` eg: "Abdul"
# - Binary 1/0 OR True/False --> `Booleans` eg: True/False

# %%
number = 15 #creation of variable

# %%
print (number) #printing of variable
# Out:
# 15

# %%
type (number) #check type of variable
# Out:
# int

# %%
id (number) # check address of variable
# Out:
# 140716795524664

# %% [markdown]
# Apply all these steps on different data types (string, integer, float & bool)
#
# 1. creating a variable `eg: variable_name = variable_value`
# 2. printing that variable `eg: print(variable_name)`
# 3. check the type of variable `eg: type(variable_name)`
# 4. check the address of the variable `eg: id(variable_name)`

# %%
# variabl_name = varibale_value
boolean_var = True

# %%
print (boolean_variable)
# Out:
# True

# %%
type (boolean_var) # type(variable_name)
# Out:
# bool

# %%
id (boolean_var) # give us address
# Out:
# 140716794628864

# %% [markdown]
# ## Operators
#
# - Addition `+`
# - Subtraction `-`
# - Multiplication `*`
# - Dividion `/`
# - Power `**`

# %%
2+5
# Out:
# 7

# %%
5-3
# Out:
# 2

# %%
9*9
# Out:
# 81

# %%
81/9 #Note that divide give results in "FLOAT"
# Out:
# 9.0

# %%
2**3 # 2*2*2
# Out:
# 8

# %%
string_var = "Abdul"
print (string_var)
# Out:
# Abdul
