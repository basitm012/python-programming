# %%
print("name")
# Out:
# name

# %% [markdown]
# ## **Variables**

# %%
name = "Abdul Basit"
name1 = "Muhammad"
name2 = "Usama"

# %%
print (name)
print (name1)
# Out:
# Abdul Basit
# Muhammad

# %%
print (name2)
# Out:
# Usama

# %%
type(name)
# Out:
# str

# %%
id (name)
# Out:
# 1867526937200

# %% [markdown]
# #### Datatypes
# - Numbers → `Integers` eg: 35
# - Decimal → `float` eg: 35.5
# - Characters/Alphats → `string` eg: "Abdul Basit"
# - Binary 1/0 OR True/Flase → `Booleans` eg: True/False

# %%
number = 500 #creation of variable
weight = 40.6

# %%
print(number)
# Out:
# 500

# %%
type(number)
# Out:
# int

# %%
id(number)
# Out:
# 1867526012080

# %%
print(weight)
# Out:
# 40.6

# %%
type(weight)
# Out:
# float

# %%
id(weight)
# Out:
# 1867502082800

# %%
boolean_var = True

# %%
print(boolean_var)
# Out:
# True

# %%
type(boolean_var)
# Out:
# bool

# %%
id(boolean_var)
# Out:
# 140710899010304

# %% [markdown]
# ## **Operators**
# - Addition `+`
# - Subtraction `-`
# - Multiplication `*`
# - Divide `/`
# - Power `**`

# %%
2+5
# Out:
# 7

# %%
5-3
# Out:
# 2

# %%
7/5  #Divide will always give results in "FLOAT"
# Out:
# 1.4

# %%
8/4
# Out:
# 2.0

# %%
6*6
# Out:
# 36

# %%
2**3 # means:2*2*2 or 2^2
# Out:
# 8

# %% [markdown]
# #### Unfamiliar Operator
# - Reminder/Modulus `%`
# - Floor `//`

# %%
20/5
# Out:
# 4.0

# %%
# 3*6 = 18
# 3*7 = 21
# least number from 20 is 18 so.. 
# 18 - 20 = 2 (i.e. reminder)

20 % 3
# Out:
# 2

# %%
13 % 4
# Out:
# 1

# %%
# 13/4 => 3.25
## Hide Numbers after decimal
13//4
# Out:
# 3

# %%
# 20/3 = 6.66
20//3
# Out:
# 6

# %% [markdown]
# #### Expressions (BODMAS)

# %%
# = ((5*4) + (4-2))-5
# = (20 + 2) - 5
# = 22 - 5
# = 17
((5*4) + (4-2))-5
# Out:
# 17

# %%
((((4*2)+2)/5)*3) +1
# Out:
# 7.0

# %% [markdown]
# ## **Naming Convention and Reserve Keywords**
# - id
# - type
# - print
# - if, else, elif
#
# Rules:
# - Don't have number in start
# - Naming can't have spaces (tip: use underscore)
# - Can't use reserve keywords
#
# Tips:
# Always keep the name meaning full and consice
# Examples:
# - name = "Abdul" --> Good
# - city = "Muhammad" --> wrong
# - My_name_is = "Qasim" --> not good
#
# ##### **Reserve Keywords:**
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Conditional Statements
# - if internet available → Class Will be conducted
# - if internet not available → There will be no class.

# %%
internet = False

# %%
if internet:
    print ("Class will be conducted")
    print ("Go to Institue")
    print ("Attend Class")

else:
    print ("There will be no class")
# Out:
# There will be no class

# %% [markdown]
# Q: Write a python code that check the age. If age is greater then 18 then eligible for CNIC else not elibigle

# %%
Age = 17

if Age >= 18:
    print("You are eligibe for applying CNIC")
else:
    print("You are not eligibe for CNIC yet.")
# Out:
# You are not eligibe for CNIC yet.

# %% [markdown]
# #### Conditional Operators
# - Greater then `>`
# - Less then `<`
# - Not equal to `!=`
# - Greater then and Equal to `>=`
# - Less then and Equal to `<=`
# - equals to `==`

# %%
5>2
# Out:
# True

# %%
3 > 7
# Out:
# False

# %%
5 != 6
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
40 >= 41
# Out:
# False

# %%
40 >= 41

# %%
print("Abdul")
# Out:
# Abdul

# %%
print("Usama")
# Out:
# Usama

# %%
print("hi")
# Out:
# hi
